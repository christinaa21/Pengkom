# %% [markdown]
# ***PROBLEM 1***
# ---
#
# ---
#
# NIM/Nama : 16521224/Christina Wijaya
#
# Tanggal  : 28 November 2021
#
# Deskripsi: Menuliskan:
#
#             1. Banyaknya data
#
#             2. 10 data pertama
#
#             3. Data ke-50 sampai 60 (inklusif: data ke-50, data ke-51, ..., data ke-60)
#
#             4. Banyaknya mahasiswa tiap fakultas
#
#             5. Nilai korelasi antara nilai fisika dan kimia, serta penjelasannya

# %% [markdown]
# **Import Data**

# %%
import pandas as pd
df = pd.read_csv('H05.csv')
df
# Out:
#                           nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 0         Farhan Fathur Rahman    FMIPA      57.21      34.14      38.93
# 1               Steven Margono    FMIPA      67.43      51.50      57.20
# 2                 Ryan Sentosa    SAPPK      90.62      37.38      40.73
# 3         Muhajah Babny Muslim    FMIPA      72.31      38.80      44.79
# 4             Alvin Natawiguna     FTSL      65.45      57.67      56.39
# ...                        ...      ...        ...        ...        ...
# 5130               Khoirrashif    SITHR      66.14      46.82      56.74
# 5131      Jefri Hendri Adriano     FTSL      53.68      34.74      33.76
# 5132               Iki Hidayat     FITB      69.63      35.04      37.65
# 5133  Muhammad Nashir Sitompul      FTI      79.69      39.06      50.17
# 5134     Billy Richardo Sagala     STEI      68.68      51.23      66.18
#
# [5135 rows x 5 columns]

# %% [markdown]
# **1. Banyaknya Data**

# %%
print("Jumlah kolom(columns):", len(df.columns))
print("Jumlah baris(rows):", len(df))
# Out:
# Jumlah kolom(columns): 5
# Jumlah baris(rows): 5135

# %% [markdown]
# **2. 10 Data Pertama**

# %%
df[:10]
# Out:
#                              nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 0            Farhan Fathur Rahman    FMIPA      57.21      34.14      38.93
# 1                  Steven Margono    FMIPA      67.43      51.50      57.20
# 2                    Ryan Sentosa    SAPPK      90.62      37.38      40.73
# 3            Muhajah Babny Muslim    FMIPA      72.31      38.80      44.79
# 4                Alvin Natawiguna     FTSL      65.45      57.67      56.39
# 5                   Sasti Safitri     FTSL      60.58      41.91      51.55
# 6             Dani Yulianto Putra     FTSL      51.67      35.05      48.69
# 7  Nabila Febitsukarizky Bunyamin     FTTM      71.66      67.61      69.75
# 8             Ratna Siti Khodijah      FTI      73.06      59.16      59.48
# 9                    Gita Partiwi     FTSL      69.57      38.84      48.17

# %% [markdown]
# **3. Data ke-50 Sampai 60 (Inklusif: data ke-50, data ke-51, ..., data ke-60)**

# %%
df[50:61]
# Out:
#                         nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 50      Arief Syakur Sutedjo     FTTM      84.40      61.21      73.91
# 51         Fayi Raihan Saleh    FMIPA      60.62      32.57      42.34
# 52          Erna Kristiawati      FTI      67.48      46.78      52.30
# 53                    Albert    SAPPK      70.27      50.10      54.01
# 54  M Jazztyan Indra Pradana     STEI      53.40      43.06      60.30
# 55      Moch Ginanjar Busiri    FMIPA      74.29      38.44      49.15
# 56              Aisya Tamara     FITB      71.49      35.86      37.41
# 57        Tyas Arum Widayati    SAPPK      68.57      37.02      53.25
# 58                Arif Saleh      FTI     100.00      59.79      55.33
# 59     Windy Diwita Nisaekti      FTI      67.15      57.72      54.24
# 60             Alif Aviano S     STEI      54.11      58.01      73.17

# %% [markdown]
# **4. Banyaknya Mahasiswa Tiap Fakultas**

# %%
df['fakultas'].value_counts()
# Out:
# FTI      834
# STEI     777
# FTSL     660
# FMIPA    627
# FTTM     579
# FTMD     480
# FITB     403
# SAPPK    315
# SITHR    282
# SITHS    178
# Name: fakultas, dtype: int64

# %% [markdown]
# **5. Nilai Korelasi Antara Nilai Fisika dan Kimia, serta Penjelasannya**

# %%
print('Nilai korelasi antara nilai fisika dan kimia:', df['nilai_fis'].corr(df['nilai_kim']), '\n')
print('Nilai korelasi tersebut bernilai positif dan mendekati 1. Ini berarti data nilai fisika dan nilai kimia berkorelasi lurus.\n' +
      'Berkorelasi lurus artinya nilai fisika dan nilai kimia cenderung menuju ke arah yang sama. Semakin besar nilai fisika, \n' +
      'maka semakin besar pula nilai kimia. Begitu pula sebaliknya.')
# Out:
# Nilai korelasi antara nilai fisika dan kimia: 0.7988187423880274
#
# Nilai korelasi tersebut bernilai positif dan mendekati 1. Ini berarti data nilai fisika dan nilai kimia berkorelasi lurus.
# Berkorelasi lurus artinya nilai fisika dan nilai kimia cenderung menuju ke arah yang sama. Semakin besar nilai fisika,
# maka semakin besar pula nilai kimia. Begitu pula sebaliknya.
