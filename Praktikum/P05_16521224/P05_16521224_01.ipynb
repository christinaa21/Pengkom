# %% [markdown]
# ***PROBLEM 1***
# ---
#
# ---
#
# NIM/Nama : 16521224/Christina Wijaya
#
# Tanggal  : 1 Desember 2021
#
# Deskripsi: Menuliskan:
#
#             1. Banyaknya data.
#
#             2. Pajak bangunan per tahun terbesar.
#
#             3. 5 rumah dengan harga sewa per tahun terbesar.
#
#             4. Rumah yang berada di kota Rio de Janeiro.
#
#             5. Nilai korelasi antara jumlah tempat parkir dengan pajak tanah per tahun, serta penjelasannya.

# %% [markdown]
# **Import Data**

# %%
import pandas as pd
df = pd.read_csv('P05-02.csv')

# %% [markdown]
# **1. Banyaknya data.**

# %%
print("Jumlah kolom(columns):", len(df.columns))
print("Jumlah baris(rows):", len(df))
# Out:
# Jumlah kolom(columns): 13
# Jumlah baris(rows): 8231

# %% [markdown]
# **2. Pajak bangunan per tahun terbesar.**

# %%
# Cara 1
print("Pajak bangunan per tahun terbesar =", df['property_tax'].max())

# Cara 2
property_tax_max = df['property_tax'].idxmax()
df[property_tax_max:property_tax_max+1]
# Out:
# Pajak bangunan per tahun terbesar = 313700
#            city  area  rooms  bathroom  parking_spaces  floor     animal  \
# 5114  Sao Paulo    42      1         2               1      6  not acept
#
#           furniture  homeowner_tax  rent_amount  property_tax  fire_insurance  \
# 5114  not furnished            690         2500        313700              32
#
#        total
# 5114  316900

# %% [markdown]
# **3. 5 rumah dengan harga sewa per tahun terbesar.**

# %%
df.sort_values(['rent_amount'], ascending=0)[:5]
# Out:
#            city  area  rooms  bathroom  parking_spaces  floor     animal  \
# 1978  Sao Paulo    80      2         1               1      1      acept
# 933   Sao Paulo   315      3         5               2     14  not acept
# 2166  Sao Paulo   285      4         5               4      6      acept
# 1302  Sao Paulo   410      4         5               5      1      acept
# 129   Sao Paulo   660      4         5               5     12      acept
#
#           furniture  homeowner_tax  rent_amount  property_tax  fire_insurance  \
# 1978  not furnished            875        24000             0             305
# 933   not furnished           4300        20000           959             254
# 2166      furnished         200000        20000          1834             254
# 1302  not furnished              0        20000             0             254
# 129       furnished           4800        20000          1750             254
#
#        total
# 1978   25180
# 933    25510
# 2166  222100
# ...

# %% [markdown]
# **4. Rumah yang berada di kota Rio de Janeiro.**

# %%
df.loc[df['city'] == "Rio de Janeiro"]
# Out:
#                 city  area  rooms  bathroom  parking_spaces  floor     animal  \
# 5     Rio de Janeiro    72      2         1               0      7      acept
# 8     Rio de Janeiro    35      1         1               0      2      acept
# 15    Rio de Janeiro    88      2         3               1      9  not acept
# 16    Rio de Janeiro    56      2         1               0      8      acept
# 19    Rio de Janeiro    90      3         2               1      7      acept
# ...              ...   ...    ...       ...             ...    ...        ...
# 8208  Rio de Janeiro    60      2         2               0     13      acept
# 8215  Rio de Janeiro   250      3         2               1     11      acept
# 8224  Rio de Janeiro    98      2         1               0      1      acept
# 8229  Rio de Janeiro    70      3         3               0      8  not acept
# 8230  Rio de Janeiro   120      2         2               2      8      acept
#
# ...

# %% [markdown]
# **5. Nilai korelasi antara jumlah tempat parkir dengan pajak tanah per tahun, serta penjelasannya.**

# %%
print('Nilai korelasi antara jumlah tempat parkir dengan pajak tanah per tahun =', df['parking_spaces'].corr(df['homeowner_tax']), '\n')

print('Diperoleh nilai korelasi positif, namun tergolong ke dalam low positif correlation (berkorelasi lurus namun tingkat korelasinya rendah) \n' +
      'bahkan hampir termasuk no correlation (tidak berkorelasi) karena nilainya mendekati 0. Hal ini menunjukkan bahwa hampir tidak ada korelasi \n' +
      'antara jumlah tempat parkir dan pajak tanah per tahun, namun sebagian kecil data menunjukkan bahwa semakin banyak jumlah tempat parkir,\n' +
      'semakin tinggi juga pajak tanah per tahunnya.')
# Out:
# Nilai korelasi antara jumlah tempat parkir dengan pajak tanah per tahun = 0.027585689636765953
#
# Diperoleh nilai korelasi positif, namun tergolong ke dalam low positif correlation (berkorelasi lurus namun tingkat korelasinya rendah)
# bahkan hampir termasuk no correlation (tidak berkorelasi) karena nilainya mendekati 0. Hal ini menunjukkan bahwa hampir tidak ada korelasi
# antara jumlah tempat parkir dan pajak tanah per tahun, namun sebagian kecil data menunjukkan bahwa semakin banyak jumlah tempat parkir,
# semakin tinggi juga pajak tanah per tahunnya.
